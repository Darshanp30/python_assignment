# %%
x = 3
y = 5
xy = 'hey'
print(x+y,xy)
# Out:
# 8 hey

# %%
print("""My name is Darshan Patil M.P.
I love Python""")
# Out:
# My name is Darshan Patil M.P.
# I love Python

# %%
string1 = 'World'
print('Hello',string1)
string2 = '!'
print('Hello',string1,string2)
# Out:
# Hello World
# Hello World !

# %%
print('Hello' +string1 +string2)
# Out:
# HelloWorld!

# %%
print("Jan\nFeb\nMar\nApr\nMay\nJun\nJul\nAug")
# Out:
# Jan
# Feb
# Mar
# Apr
# May
# Jun
# Jul
# Aug

# %%
print("I want\\n tp be printed.")
# Out:
# I want\n tp be printed.

# %%
x = 10
print(type(x))
s = 'abc'
print(type(s))
value = True 
print(type(value))
percent = 90.00
print(type(percent))
# Out:
# <class 'int'>
# <class 'str'>
# <class 'bool'>
# <class 'float'>
